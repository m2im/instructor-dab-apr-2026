# %%
# Will this work?
1st_place_score = 98
print(1st_place_score)
# Out:
#   Cell In[1], line 2
#     1st_place_score = 98
#     ^
# SyntaxError: invalid decimal literal

# %%
# Will this code print 100?
bonus = 50
Bonus = 60

print(bonus + Bonus)
# Out:
# 110

# %%
# Is this a valid name?
_secret_key = "ABC-123"
print(_secret_key)
# Out:
# ABC-123

# %%
# Can we use this specific name?
Class = "Data Analytics"
print(Class)
# Out:
# Data Analytics

# %%
# Is this allowed?
userName = "Jane"
print(userName)
# Out:
# Jane

# %%
x,y = 101,102

# %%
print(x,y)
# Out:
# 101 102

# %%
student_count = 25

# %%
type(student_count)
# Out:
# int

# %%
gpa_average = 3.75

# %%
type(gpa_average)
# Out:
# float

# %%
cohort_id = "dab-apr-2026"

# %%
type(cohort_id)
# Out:
# str

# %%
is_class_active = True

# %%
type(is_class_active)
# Out:
# bool

# %%
res = 10 + 5.0

# %%
type(res)
# Out:
# float

# %%
res1 = "10" + "5"

# %%
print(res1)
# Out:
# 105

# %%
type(res1)
# Out:
# str

# %%
res2 = 10 > 5

# %%
print(res2)
# Out:
# True

# %%
type(res2)
# Out:
# bool

# %% [markdown]
# ### Arithmetic Operations

# %%
x = 10
y = 3

# %%
print(x + y)
# Out:
# 13

# %%
print(x - y)
# Out:
# 7

# %%
print (x * y)
# Out:
# 30

# %%
print (x / y)
# Out:
# 3.3333333333333335

# %%
print (x % y)
# Out:
# 1

# %%
print(x ** y)
# Out:
# 1000

# %%
print(x // y)
# Out:
# 3

# %% [markdown]
# ### Assignment Operators

# %%
score = 100

# %%
score += 10

# %%
score = score + 10

# %%
print (score)
# Out:
# 120

# %%
score -= 5

# %%
print(score)
# Out:
# 115

# %%
score *= 2 
print(score)
# Out:
# 200

# %%
score /= 10
print(score)
# Out:
# 20.0

# %%
type(score)
# Out:
# float

# %% [markdown]
# ### Comparison operators

# %%
a = 15
b = 20

# %%
print(a == b)
# Out:
# False

# %%
a = b

# %%
print(a)
# Out:
# 20

# %%
print(a != b)
# Out:
# True

# %%
print(a > 15)
# Out:
# False

# %% [markdown]
# ### Logical Operators

# %%
is_sunny = True
is_warm = False

# %%
print(is_sunny and is_warm)
# Out:
# False
